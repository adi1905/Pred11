# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import warnings
import csv
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
warnings.filterwarnings("ignore")

# %% [markdown]
# # Extract the matches data that happened between 2010-2019

# %%
html_text = requests.get("https://stats.espncricinfo.com/ci/engine/records/index.html?id=201;type=decade")
soup = BeautifulSoup(html_text.content,"html.parser")
table = soup.find("table",class_ = "recordsTable")
ul = table.find_all("ul")
a = ul[1].find_all("a")
matches_url = ["https://stats.espncricinfo.com" + anchor['href'] for anchor in a]
print(matches_url)
# Out:
# ['https://stats.espncricinfo.com/ci/engine/records/team/match_results_year.html?class=1;id=201;type=decade', 'https://stats.espncricinfo.com/ci/engine/records/team/match_results_year.html?class=2;id=201;type=decade', 'https://stats.espncricinfo.com/ci/engine/records/team/match_results_year.html?class=3;id=201;type=decade']

# %%
test_url = matches_url[0]
odi_url = matches_url[1]
t20_url = matches_url[2]

# %%
def get_links_by_year(url):
    text_content = requests.get(url)
    soup = BeautifulSoup(text_content.content,"html.parser")
    a = soup.find_all("a",class_ = "QuoteSummary")
    links = ["https://stats.espncricinfo.com" + anchor['href'] for anchor in a]
    return links

# %%
test_year_links = get_links_by_year(test_url)
odi_year_links = get_links_by_year(odi_url)
t20_year_links = get_links_by_year(t20_url)

# %%
test_year_links[0]
# Out:
# 'https://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2010;type=year'

# %%
def scrap_matches_by_formats(links_list):
    df = pd.DataFrame()
    match_links = []
    for link in links_list:
        html_text = requests.get(link)
        soup = BeautifulSoup(html_text.content,"html.parser")
        table = soup.find("table",class_ = "engineTable")
        columns = []
        for th in table.find('thead').find_all('th'):
            columns.append(th.text.strip())
        data = []
        for tr in table.find('tbody').find_all('tr'):
            row = []
            for td in tr.find_all('td'):
                row.append(td.text.strip())
                if td.find('a'):
                    link = td.find('a')['href']
                    if 'match' in link:
                        match_links.append("https://stats.espncricinfo.com" + link)
            if row[2] == 'no result': 
                if match_links:
                    match_links.pop() 
                continue 
            data.append(row)
        columns = ['Team 1','Team 2','Winner','Margin','Ground','Match Date','Match id']   
        for row in data:
            match = row[0] + " vs " + row[1]
            row.insert(0, match)
            df = df.append(pd.Series(row, index=['Match'] + columns), ignore_index=True)
    return df, match_links

# %%
test_matches_df,test_matches_link = scrap_matches_by_formats(test_year_links)
odi_matches_df,odi_matches_link = scrap_matches_by_formats(odi_year_links)
t20_matches_df,t20_matches_link = scrap_matches_by_formats(t20_year_links)

# %%
t20_matches_df.head()
# Out:
#                        Match       Team 1      Team 2       Winner  \
# 0     Afghanistan vs Ireland  Afghanistan     Ireland      Ireland
# 1          Kenya vs Scotland        Kenya    Scotland        Kenya
# 2          Canada vs Ireland       Canada     Ireland       Canada
# 3  New Zealand vs Bangladesh  New Zealand  Bangladesh  New Zealand
# 4      Afghanistan vs Canada  Afghanistan      Canada  Afghanistan
#
#        Margin         Ground   Match Date    Match id
# 0   5 wickets  Colombo (PSS)  Feb 1, 2010  T20I # 128
# 1  10 wickets  Nairobi (Gym)  Feb 1, 2010  T20I # 129
# 2      4 runs  Colombo (SSC)  Feb 3, 2010  T20I # 130
# 3  10 wickets       Hamilton  Feb 3, 2010  T20I # 131
# 4   5 wickets  Colombo (SSC)  Feb 4, 2010  T20I # 132

# %%
len(t20_matches_link)
# Out:
# 875

# %%
def save_to_csv(csvfile,df):
    df.to_csv(csvfile,index=False)

# %%
save_to_csv("odi_matches_info.csv",odi_matches_df)
save_to_csv("test_matches_info.csv",test_matches_df)
save_to_csv("t20_matches_info.csv",t20_matches_df)

# %% [markdown]
# # Extract the batting and bowling stats of every match

# %%
def odi_and_t20_matches_stats(match_url):
    batting_df = pd.DataFrame()
    bowling_df = pd.DataFrame()
    
    html_content = requests.get(match_url)
    soup = BeautifulSoup(html_content.content,"html.parser")
    try:
        batting_and_bowling = soup.find_all("div",class_ = "ds-p-0")[1:3]
        match_number_div = soup.find_all("div",class_ = "ds-p-0")[3]
        match_number = match_number_div.find_all("span",class_ = "ds-text-tight-s ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block")[-1].text.split(" ")[-1]
    #     print(match_number)
        innings_batting_data = []
        innings_bowling_data = []
        inningsTeam = soup.find_all("span",class_ = "ds-text-title-xs ds-font-bold ds-capitalize")
        team1 = inningsTeam[0].text
        team2 = inningsTeam[1].text
        match_name = team1 + " Vs"  + team2
        print(f"Processing match: {match_name} with match id: {match_number}")
        for div in batting_and_bowling:
            innings_team_name = inningsTeam.pop(0).text
            table = div.find_all("table")
            innings_batting = table[0]
            batting_columns = []
            for th in innings_batting.find("thead").find_all('th'):
                batting_columns.append(th.text.strip())
            batting_data = []
            for tr in innings_batting.find("tbody").find_all('tr'):
                batting_row = []
                for td in tr.find_all("td"):
                    batting_row.append(td.text.strip())
                if any(batting_row):
                    batting_data.append(batting_row) 
            batting_columns = ['Batsman Name','Dismissal','Runs','Balls','M','4s','6s','Strike Rate']
            innings_batting_df = pd.DataFrame(batting_data, columns=batting_columns)
            innings_batting_df = innings_batting_df[~innings_batting_df['Batsman Name'].str.contains('Extras|TOTAL|Did not bat|Fall of wickets')]
            innings_batting_df.insert(0,"Match Name",match_name)
            innings_batting_df.insert(1, "teamInnings", innings_team_name)
            innings_batting_df.insert(2, "Batting Position", range(1, 1+len(innings_batting_df)))
            innings_batting_df.insert(10,"Match id",match_number)
            batting_df = batting_df.append(innings_batting_df, ignore_index=True)

            #bowling scorecard
            innings_bowling = table[1]
            bowling_columns = []
            for th in innings_bowling.find("thead").find_all('th'):
                bowling_columns.append(th.text.strip())
            bowling_data = []
            for tr in innings_bowling.find("tbody").find_all('tr'):
                bowling_row = []
                for td in tr.find_all("td"):
                    bowling_row.append(td.text.strip())
                if len(bowling_row)!=1:
                    bowling_data.append(bowling_row) 
            bowling_columns = ['Bowler Name','Over','Maiden','Runs','Wickets','Economy','dots','fours','sixes','wides','no balls']
            innings_bowling_df = pd.DataFrame(bowling_data, columns=bowling_columns)
            if innings_team_name == team1:
                innings_team_name = team2
            else:
                innings_team_name = team1
            innings_bowling_df.insert(0, "match", match_name)
            innings_bowling_df.insert(1, "teamInnings", innings_team_name)
            innings_bowling_df.insert(13,"Match Id",match_number)
            bowling_df = bowling_df.append(innings_bowling_df, ignore_index=True)
    except:
        pass
        
    return batting_df,bowling_df

# %%
odi_matches_link[400]
# Out:
# 'https://stats.espncricinfo.com/ci/engine/match/567371.html'

# %% [markdown]
# # save the batting and bowling data in two seperate files

# %%
#saving odi matches scorecard
combined_odi_batting_df = pd.DataFrame()
combined_odi_bowling_df = pd.DataFrame()

# Loop through the match URLs
for match_url in odi_matches_link:
    batting_df, bowling_df = odi_and_t20_matches_stats(match_url)
    combined_odi_batting_df = combined_odi_batting_df.append(batting_df)
    combined_odi_bowling_df = combined_odi_bowling_df.append(bowling_df)

# Write the combined batting and bowling dataframes to CSV files
combined_odi_batting_df.to_csv('odi_batting_data.csv', index=False)
combined_odi_bowling_df.to_csv('odi_bowling_data.csv', index=False)
# Out:
# Processing match: Bangladesh VsSri Lanka with match id: 2937
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 7
#       5 # Loop through the match URLs
#       6 for match_url in odi_matches_link:
# ----> 7     batting_df, bowling_df = odi_and_t20_matches_stats(match_url)
#       8     combined_odi_batting_df = combined_odi_batting_df.append(batting_df)
#       9     combined_odi_bowling_df = combined_odi_bowling_df.append(bowling_df)
#
# Cell In[24], line 5, in odi_and_t20_matches_stats(match_url)
#       2 batting_df = pd.DataFrame()
#       3 bowling_df = pd.DataFrame()
# ----> 5 html_content = requests.get(match_url)
#       6 soup = BeautifulSoup(html_content.content,"html.parser")
#       7 try:
#
# File /usr/lib/python3/dist-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 r"""Sends a GET request.
#      65
#      66 :param url: URL for the new :class:`Request` object.
#    (...)
#      71 :rtype: requests.Response
#      72 """
#      74 kwargs.setdefault('allow_redirects', True)
# ---> 75 return request('get', url, params=params, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/api.py:60, in request(method, url, **kwargs)
#      56 # By using the 'with' statement we are sure the session is closed, thus we
#      57 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      58 # cases, and look like a memory leak in others.
#      59 with sessions.Session() as session:
# ---> 60     return session.request(method=method, url=url, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:533, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528 send_kwargs = {
#     529     'timeout': timeout,
#     530     'allow_redirects': allow_redirects,
#     531 }
#     532 send_kwargs.update(settings)
# --> 533 resp = self.send(prep, **send_kwargs)
#     535 return resp
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:668, in Session.send(self, request, **kwargs)
#     665 gen = self.resolve_redirects(r, request, **kwargs)
#     667 # Resolve redirects if allowed.
# --> 668 history = [resp for resp in gen] if allow_redirects else []
#     670 # Shuffle things around if there's history.
#     671 if history:
#     672     # Insert the first (original) request at the start
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:668, in <listcomp>(.0)
#     665 gen = self.resolve_redirects(r, request, **kwargs)
#     667 # Resolve redirects if allowed.
# --> 668 history = [resp for resp in gen] if allow_redirects else []
#     670 # Shuffle things around if there's history.
#     671 if history:
#     672     # Insert the first (original) request at the start
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:214, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     212 extract_cookies_to_jar(prepared_request._cookies, req, resp.raw)
#     213 merge_cookies(prepared_request._cookies, self.cookies)
# --> 214 prepared_request.prepare_cookies(prepared_request._cookies)
#     216 # Rebuild auth and proxy information.
#     217 proxies = self.rebuild_proxies(prepared_request, proxies)
#
# File /usr/lib/python3/dist-packages/requests/models.py:572, in PreparedRequest.prepare_cookies(self, cookies)
#     569 else:
#     570     self._cookies = cookiejar_from_dict(cookies)
# --> 572 cookie_header = get_cookie_header(self._cookies, self)
#     573 if cookie_header is not None:
#     574     self.headers['Cookie'] = cookie_header
#
# File /usr/lib/python3/dist-packages/requests/cookies.py:142, in get_cookie_header(jar, request)
#     136 """
#     137 Produce an appropriate Cookie header string to be sent with `request`, or None.
#     138
#     139 :rtype: str
#     140 """
#     141 r = MockRequest(request)
# --> 142 jar.add_cookie_header(r)
#     143 return r.get_new_headers().get('Cookie')
#
# File /usr/lib/python3.8/http/cookiejar.py:1365, in CookieJar.add_cookie_header(self, request)
#    1361 try:
#    1363     self._policy._now = self._now = int(time.time())
# -> 1365     cookies = self._cookies_for_request(request)
#    1367     attrs = self._cookie_attrs(cookies)
#    1368     if attrs:
#
# File /usr/lib/python3.8/http/cookiejar.py:1291, in CookieJar._cookies_for_request(self, request)
#    1289 cookies = []
#    1290 for domain in self._cookies.keys():
# -> 1291     cookies.extend(self._cookies_for_domain(domain, request))
#    1292 return cookies
#
# File /usr/lib/python3.8/http/cookiejar.py:1280, in CookieJar._cookies_for_domain(self, domain, request)
#    1278 cookies_by_name = cookies_by_path[path]
#    1279 for cookie in cookies_by_name.values():
# -> 1280     if not self._policy.return_ok(cookie, request):
#    1281         _debug("   not returning cookie")
#    1282         continue
#
# File /usr/lib/python3.8/http/cookiejar.py:1102, in DefaultCookiePolicy.return_ok(self, cookie, request)
#    1100     fn_name = "return_ok_"+n
#    1101     fn = getattr(self, fn_name)
# -> 1102     if not fn(cookie, request):
#    1103         return False
#    1104 return True
#
# File /usr/lib/python3.8/http/cookiejar.py:1116, in DefaultCookiePolicy.return_ok_verifiability(self, cookie, request)
#    1115 def return_ok_verifiability(self, cookie, request):
# -> 1116     if request.unverifiable and is_third_party(request):
#    1117         if cookie.version > 0 and self.strict_rfc2965_unverifiable:
#    1118             _debug("   third-party RFC 2965 cookie during unverifiable "
#    1119                    "transaction")
#
# File /usr/lib/python3.8/http/cookiejar.py:730, in is_third_party(request)
#     720 """
#     721
#     722 RFC 2965, section 3.3.6:
#    (...)
#     727
#     728 """
#     729 req_host = request_host(request)
# --> 730 if not domain_match(req_host, reach(request.origin_req_host)):
#     731     return True
#     732 else:
#
# File /usr/lib/python3.8/http/cookiejar.py:578, in domain_match(A, B)
#     576 if not B.startswith("."):
#     577     return False
# --> 578 if not is_HDN(B[1:]):
#     579     return False
#     580 return True
#
# File /usr/lib/python3.8/http/cookiejar.py:539, in is_HDN(text)
#     537 if text == "":
#     538     return False
# --> 539 if text[0] == "." or text[-1] == ".":
#     540     return False
#     541 return True
#
# KeyboardInterrupt:

# %%
combined_odi_bowling_df.head()
# Out:
#                     match teamInnings           Bowler Name Over Maiden Runs  \
# 0  Bangladesh VsSri Lanka   Sri Lanka      Nuwan Kulasekara   10      1   46
# 1  Bangladesh VsSri Lanka   Sri Lanka    Chanaka Welegedara    8      0   39
# 2  Bangladesh VsSri Lanka   Sri Lanka  Tillakaratne Dilshan    3      0   16
# 3  Bangladesh VsSri Lanka   Sri Lanka        Suranga Lakmal    9      1   63
# 4  Bangladesh VsSri Lanka   Sri Lanka          Suraj Randiv   10      0   51
#
#   Wickets Economy dots fours sixes wides no balls Match Id
# 0       1    4.60   28     2     0     1        0     2937
# 1       0    4.87   27     5     0     1        0     2937
# 2       1    5.33   11     1     0     1        0     2937
# 3       2    7.00   32     8     2     5        0     2937
# 4       2    5.10   28     3     1     2        0     2937

# %% [markdown]
# # saving the t20 batting anf bowling data in csvs

# %%
#saving t20 matches scorecard
combined_t20_batting_df = pd.DataFrame()
combined_t20_bowling_df = pd.DataFrame()

# Loop through the match URLs
for match_url in t20_matches_link:
    batting_df, bowling_df = odi_and_t20_matches_stats(match_url)
    combined_t20_batting_df = combined_t20_batting_df.append(batting_df)
    combined_t20_bowling_df = combined_t20_bowling_df.append(bowling_df)

 # Write the combined batting and bowling dataframes to CSV files
combined_t20_batting_df.to_csv('t20_batting_data.csv', index=False)
combined_t20_bowling_df.to_csv('t20_bowling_data.csv', index=False)
# Out:
# Processing match: Afghanistan VsIreland with match id: 128
# Processing match: Scotland VsKenya with match id: 129
# Processing match: Canada VsIreland with match id: 130
# Processing match: Bangladesh VsNew Zealand with match id: 131
# Processing match: Canada VsAfghanistan with match id: 132
# Processing match: Scotland VsKenya with match id: 133
# Processing match: Australia VsPakistan with match id: 134
# Processing match: Afghanistan VsIreland with match id: 135
# Processing match: Canada VsNetherlands with match id: 136
# Processing match: Afghanistan VsScotland with match id: 137
# Processing match: Canada VsKenya with match id: 138
# Processing match: Kenya VsNetherlands with match id: 139
# Processing match: Ireland VsScotland with match id: 140
# Processing match: Afghanistan VsNetherlands with match id: 141
# Processing match: Ireland VsNetherlands with match id: 142
# Processing match: Ireland VsAfghanistan with match id: 143
# Processing match: Pakistan VsEngland with match id: 144
# Processing match: England VsPakistan with match id: 145
# Processing match: Australia VsWest Indies with match id: 146
# Processing match: West Indies VsAustralia with match id: 147
# Processing match: New Zealand VsAustralia with match id: 148
# Processing match: New Zealand VsAustralia with match id: 149
# Processing match: Zimbabwe VsWest Indies with match id: 150
# Processing match: Sri Lanka VsNew Zealand with match id: 151
# Processing match: West Indies VsIreland with match id: 152
# Processing match: Afghanistan VsIndia with match id: 153
# Processing match: Pakistan VsBangladesh with match id: 154
# Processing match: India VsSouth Africa with match id: 155
# Processing match: Australia VsPakistan with match id: 156
# Processing match: Sri Lanka VsZimbabwe with match id: 157
# Processing match: England VsWest Indies with match id: 158
# Processing match: Zimbabwe VsNew Zealand with match id: 159
# Processing match: Australia VsBangladesh with match id: 161
# Processing match: South Africa VsAfghanistan with match id: 162
# Processing match: Pakistan VsEngland with match id: 163
# Processing match: South Africa VsNew Zealand with match id: 164
# Processing match: Australia VsIndia with match id: 165
# Processing match: Sri Lanka VsWest Indies with match id: 166
# Processing match: New Zealand VsPakistan with match id: 167
# Processing match: England VsSouth Africa with match id: 168
# Processing match: West Indies VsIndia with match id: 169
# Processing match: Australia VsSri Lanka with match id: 170
# Processing match: Pakistan VsSouth Africa with match id: 171
# Processing match: New Zealand VsEngland with match id: 172
# Processing match: India VsSri Lanka with match id: 173
# Processing match: West Indies VsAustralia with match id: 174
# Processing match: Sri Lanka VsEngland with match id: 175
# Processing match: Pakistan VsAustralia with match id: 176
# Processing match: Australia VsEngland with match id: 177
# Processing match: South Africa VsWest Indies with match id: 178
# Processing match: South Africa VsWest Indies with match id: 179
# Processing match: New Zealand VsSri Lanka with match id: 180
# Processing match: New Zealand VsSri Lanka with match id: 181
# Processing match: Zimbabwe VsIndia with match id: 182
# Processing match: Zimbabwe VsIndia with match id: 183
# Processing match: Pakistan VsAustralia with match id: 184
# Processing match: Pakistan VsAustralia with match id: 185
# Processing match: Pakistan VsEngland with match id: 186
# Processing match: Pakistan VsEngland with match id: 187
# Processing match: Zimbabwe VsSouth Africa with match id: 188
# Processing match: South Africa VsZimbabwe with match id: 189
# Processing match: Pakistan VsSouth Africa with match id: 190
# Processing match: Pakistan VsSouth Africa with match id: 191
# Processing match: Australia VsSri Lanka with match id: 192
# Processing match: Pakistan VsNew Zealand with match id: 193
# Processing match: New Zealand VsPakistan with match id: 194
# Processing match: Pakistan VsNew Zealand with match id: 195
# Processing match: India VsSouth Africa with match id: 196
# Processing match: Australia VsEngland with match id: 197
# Processing match: Australia VsEngland with match id: 198
# Processing match: West Indies VsPakistan with match id: 199
# Processing match: India VsWest Indies with match id: 200
# Processing match: England VsSri Lanka with match id: 201
# Processing match: Sri Lanka VsAustralia with match id: 202
# Processing match: Sri Lanka VsAustralia with match id: 203
# Processing match: India VsEngland with match id: 204
# Processing match: Pakistan VsZimbabwe with match id: 205
# Processing match: Pakistan VsZimbabwe with match id: 206
# Processing match: West Indies VsEngland with match id: 207
# Processing match: West Indies VsEngland with match id: 208
# Processing match: West Indies VsBangladesh with match id: 209
# Processing match: South Africa VsAustralia with match id: 210
# Processing match: Zimbabwe VsNew Zealand with match id: 211
# Processing match: Australia VsSouth Africa with match id: 212
# Processing match: New Zealand VsZimbabwe with match id: 213
# Processing match: India VsEngland with match id: 214
# Processing match: Sri Lanka VsPakistan with match id: 215
# Processing match: Pakistan VsBangladesh with match id: 216
# Processing match: Australia VsIndia with match id: 217
# Processing match: Australia VsIndia with match id: 218
# Processing match: Zimbabwe VsNew Zealand with match id: 219
# Processing match: Zimbabwe VsNew Zealand with match id: 220
# Processing match: South Africa VsNew Zealand with match id: 221
# Processing match: New Zealand VsSouth Africa with match id: 222
# Processing match: South Africa VsNew Zealand with match id: 223
# Processing match: Kenya VsIreland with match id: 224
# Processing match: Kenya VsIreland with match id: 225
# Processing match: Pakistan VsEngland with match id: 226
# Processing match: Ireland VsKenya with match id: 227
# Processing match: England VsPakistan with match id: 228
# Processing match: England VsPakistan with match id: 229
# Processing match: Netherlands VsCanada with match id: 230
# Processing match: Scotland VsKenya with match id: 231
# Processing match: Kenya VsIreland with match id: 232
# Processing match: Netherlands VsAfghanistan with match id: 233
# Processing match: Afghanistan VsCanada with match id: 234
# Processing match: Ireland VsScotland with match id: 235
# Processing match: Canada VsIreland with match id: 236
# Processing match: Scotland VsNetherlands with match id: 237
# Processing match: Netherlands VsIreland with match id: 238
# Processing match: Canada VsScotland with match id: 239
# Processing match: Afghanistan VsIreland with match id: 240
# Processing match: West Indies VsAustralia with match id: 241
# Processing match: South Africa VsIndia with match id: 242
# Processing match: West Indies VsAustralia with match id: 243
# Processing match: Sri Lanka VsPakistan with match id: 244
# Processing match: Pakistan VsSri Lanka with match id: 245
# Processing match: West Indies VsEngland with match id: 246
# Processing match: West Indies VsNew Zealand with match id: 247
# Processing match: West Indies VsNew Zealand with match id: 248
# Processing match: Bangladesh VsIreland with match id: 249
# Processing match: Bangladesh VsIreland with match id: 250
# Processing match: Ireland VsBangladesh with match id: 251
# Processing match: Scotland VsBangladesh with match id: 252
# Processing match: Netherlands VsBangladesh with match id: 253
# Processing match: Bangladesh VsNetherlands with match id: 254
# Processing match: India VsSri Lanka with match id: 255
# Processing match: Australia VsPakistan with match id: 256
# Processing match: Pakistan VsAustralia with match id: 257
# Processing match: England VsSouth Africa with match id: 258
# Processing match: Australia VsPakistan with match id: 259
# Processing match: New Zealand VsIndia with match id: 261
# Processing match: England VsSouth Africa with match id: 262
# Processing match: Sri Lanka VsZimbabwe with match id: 263
# Processing match: Ireland VsAustralia with match id: 264
# Processing match: India VsAfghanistan with match id: 265
# Processing match: Zimbabwe VsSouth Africa with match id: 266
# Processing match: New Zealand VsBangladesh with match id: 267
# Processing match: England VsAfghanistan with match id: 268
# Processing match: South Africa VsSri Lanka with match id: 269
# Processing match: West Indies VsAustralia with match id: 270
# Processing match: Pakistan VsNew Zealand with match id: 271
# Processing match: India VsEngland with match id: 272
# Processing match: Bangladesh VsPakistan with match id: 274
# Processing match: New Zealand VsSri Lanka with match id: 275
# Processing match: West Indies VsEngland with match id: 276
# Processing match: South Africa VsPakistan with match id: 277
# Processing match: India VsAustralia with match id: 278
# Processing match: New Zealand VsEngland with match id: 279
# Processing match: West Indies VsSri Lanka with match id: 280
# Processing match: South Africa VsAustralia with match id: 281
# Processing match: Pakistan VsIndia with match id: 282
# Processing match: West Indies VsNew Zealand with match id: 283
# Processing match: Sri Lanka VsEngland with match id: 284
# Processing match: Pakistan VsAustralia with match id: 285
# Processing match: India VsSouth Africa with match id: 286
# Processing match: Sri Lanka VsPakistan with match id: 287
# Processing match: West Indies VsAustralia with match id: 288
# Processing match: West Indies VsSri Lanka with match id: 289
# Processing match: West Indies VsBangladesh with match id: 291
# Processing match: England VsIndia with match id: 292
# Processing match: New Zealand VsSouth Africa with match id: 293
# Processing match: India VsEngland with match id: 294
# Processing match: South Africa VsNew Zealand with match id: 295
# Processing match: India VsPakistan with match id: 296
# Processing match: South Africa VsNew Zealand with match id: 297
# Processing match: India VsPakistan with match id: 298
# Processing match: Australia VsSri Lanka with match id: 299
# Processing match: Sri Lanka VsAustralia with match id: 300
# Processing match: England VsNew Zealand with match id: 301
# Processing match: New Zealand VsEngland with match id: 302
# Processing match: West Indies VsAustralia with match id: 303
# Processing match: New Zealand VsEngland with match id: 304
# Processing match: Zimbabwe VsWest Indies with match id: 305
# Processing match: Pakistan VsSouth Africa with match id: 306
# Processing match: Afghanistan VsScotland with match id: 307
# Processing match: West Indies VsZimbabwe with match id: 308
# Processing match: Scotland VsAfghanistan with match id: 309
# Processing match: Kenya VsCanada with match id: 310
# Processing match: Kenya VsCanada with match id: 311
# Processing match: Sri Lanka VsBangladesh with match id: 312
# Processing match: Netherlands VsKenya with match id: 313
# Processing match: Netherlands VsKenya with match id: 314
# Processing match: Zimbabwe VsBangladesh with match id: 315
# Processing match: Bangladesh VsZimbabwe with match id: 316
# Processing match: New Zealand VsEngland with match id: 317
# Processing match: Scotland VsKenya with match id: 319
# Processing match: Kenya VsScotland with match id: 320
# Processing match: West Indies VsPakistan with match id: 321
# Processing match: Pakistan VsWest Indies with match id: 322
# Processing match: South Africa VsSri Lanka with match id: 323
# Processing match: South Africa VsSri Lanka with match id: 324
# Processing match: South Africa VsSri Lanka with match id: 325
# Processing match: Pakistan VsZimbabwe with match id: 326
# Processing match: Pakistan VsZimbabwe with match id: 327
# Processing match: Australia VsEngland with match id: 328
# Processing match: England VsAustralia with match id: 329
# Processing match: Afghanistan VsKenya with match id: 330
# Processing match: Australia VsIndia with match id: 331
# Processing match: Kenya VsAfghanistan with match id: 332
# Processing match: New Zealand VsBangladesh with match id: 333
# Processing match: Pakistan VsSouth Africa with match id: 334
# Processing match: Afghanistan VsNetherlands with match id: 335
# Processing match: South Africa VsPakistan with match id: 336
# Processing match: Afghanistan VsScotland with match id: 337
# Processing match: Ireland VsCanada with match id: 338
# Processing match: Kenya VsScotland with match id: 339
# Processing match: South Africa VsPakistan with match id: 340
# Processing match: New Zealand VsSri Lanka with match id: 341
# Processing match: Scotland VsNetherlands with match id: 342
# Processing match: Pakistan VsSouth Africa with match id: 343
# Processing match: Netherlands VsKenya with match id: 344
# Processing match: Afghanistan VsKenya with match id: 345
# Processing match: Kenya VsCanada with match id: 346
# Processing match: Scotland VsNetherlands with match id: 347
# Processing match: Ireland VsAfghanistan with match id: 348
# Processing match: Afghanistan VsPakistan with match id: 349
# Processing match: Sri Lanka VsPakistan with match id: 350
# Processing match: Sri Lanka VsPakistan with match id: 351
# Processing match: New Zealand VsWest Indies with match id: 352
# Processing match: West Indies VsNew Zealand with match id: 353
# Processing match: Australia VsEngland with match id: 354
# Processing match: England VsAustralia with match id: 355
# Processing match: Australia VsEngland with match id: 356
# Processing match: Sri Lanka VsBangladesh with match id: 357
# Processing match: Bangladesh VsSri Lanka with match id: 358
# Processing match: West Indies VsIreland with match id: 359
# Processing match: West Indies VsIreland with match id: 360
# Processing match: West Indies VsEngland with match id: 361
# Processing match: England VsWest Indies with match id: 362
# Processing match: South Africa VsAustralia with match id: 363
# Processing match: England VsWest Indies with match id: 364
# Processing match: South Africa VsAustralia with match id: 365
# Processing match: Afghanistan VsBangladesh with match id: 366
# Processing match: Nepal VsHong Kong with match id: 367
# Processing match: Zimbabwe VsIreland with match id: 368
# Processing match: United Arab Emirates VsNetherlands with match id: 369
# Processing match: Hong Kong VsAfghanistan with match id: 370
# Processing match: Nepal VsBangladesh with match id: 371
# Processing match: Netherlands VsZimbabwe with match id: 372
# Processing match: United Arab Emirates VsIreland with match id: 373
# Processing match: Nepal VsAfghanistan with match id: 374
# Processing match: Bangladesh VsHong Kong with match id: 375
# Processing match: United Arab Emirates VsZimbabwe with match id: 376
# Processing match: Ireland VsNetherlands with match id: 377
# Processing match: Pakistan VsIndia with match id: 378
# Processing match: Sri Lanka VsSouth Africa with match id: 379
# Processing match: England VsNew Zealand with match id: 380
# Processing match: Pakistan VsAustralia with match id: 381
# Processing match: West Indies VsIndia with match id: 382
# Processing match: South Africa VsNew Zealand with match id: 383
# Processing match: Netherlands VsSri Lanka with match id: 384
# Processing match: West Indies VsBangladesh with match id: 385
# Processing match: South Africa VsNetherlands with match id: 386
# Processing match: Sri Lanka VsEngland with match id: 387
# Processing match: Australia VsWest Indies with match id: 388
# Processing match: Bangladesh VsIndia with match id: 389
# Processing match: Netherlands VsNew Zealand with match id: 390
# Processing match: South Africa VsEngland with match id: 391
# Processing match: Pakistan VsBangladesh with match id: 392
# Processing match: India VsAustralia with match id: 393
# Processing match: Netherlands VsEngland with match id: 394
# Processing match: Sri Lanka VsNew Zealand with match id: 395
# Processing match: Bangladesh VsAustralia with match id: 396
# Processing match: West Indies VsPakistan with match id: 397
# Processing match: Sri Lanka VsWest Indies with match id: 398
# Processing match: South Africa VsIndia with match id: 399
# Processing match: India VsSri Lanka with match id: 400
# Processing match: Sri Lanka VsEngland with match id: 401
# Processing match: West Indies VsNew Zealand with match id: 402
# Processing match: West Indies VsNew Zealand with match id: 403
# Processing match: England VsIndia with match id: 405
# Processing match: Pakistan VsAustralia with match id: 406
# Processing match: Australia VsSouth Africa with match id: 407
# Processing match: South Africa VsAustralia with match id: 408
# Processing match: South Africa VsAustralia with match id: 409
# Processing match: Nepal VsHong Kong with match id: 410
# Processing match: New Zealand VsPakistan with match id: 411
# Processing match: New Zealand VsPakistan with match id: 412
# Processing match: South Africa VsWest Indies with match id: 413
# Processing match: South Africa VsWest Indies with match id: 414
# Processing match: South Africa VsWest Indies with match id: 415
# Processing match: Pakistan VsBangladesh with match id: 416
# Processing match: Zimbabwe VsPakistan with match id: 417
# Processing match: Zimbabwe VsPakistan with match id: 418
# Processing match: Ireland VsScotland with match id: 419
# Processing match: Ireland VsScotland with match id: 421
# Processing match: England VsNew Zealand with match id: 423
# Processing match: Netherlands VsNepal with match id: 424
# Processing match: Netherlands VsNepal with match id: 425
# Processing match: Netherlands VsNepal with match id: 426
# Processing match: Netherlands VsNepal with match id: 427
# Processing match: South Africa VsBangladesh with match id: 428
# Processing match: South Africa VsBangladesh with match id: 429
# Processing match: United Arab Emirates VsScotland with match id: 430
# Processing match: Afghanistan VsNetherlands with match id: 431
# Processing match: United Arab Emirates VsAfghanistan with match id: 432
# Processing match: Netherlands VsScotland with match id: 433
# Processing match: United Arab Emirates VsNetherlands with match id: 434
# Processing match: Afghanistan VsScotland with match id: 435
# Processing match: Nepal VsIreland with match id: 436
# Processing match: Ireland VsPapua New Guinea with match id: 437
# Processing match: Nepal VsHong Kong with match id: 438
# Processing match: Nepal VsPapua New Guinea with match id: 439
# Processing match: India VsZimbabwe with match id: 440
# Processing match: Hong Kong VsIreland with match id: 441
# Processing match: Zimbabwe VsIndia with match id: 442
# Processing match: Afghanistan VsHong Kong with match id: 443
# Processing match: Papua New Guinea VsAfghanistan with match id: 444
# Processing match: Hong Kong VsScotland with match id: 445
# Processing match: Oman VsAfghanistan with match id: 446
# Processing match: Ireland VsNetherlands with match id: 447
# Processing match: Pakistan VsSri Lanka with match id: 448
# Processing match: Sri Lanka VsPakistan with match id: 449
# Processing match: New Zealand VsZimbabwe with match id: 450
# Processing match: New Zealand VsSouth Africa with match id: 451
# Processing match: New Zealand VsSouth Africa with match id: 452
# Processing match: England VsAustralia with match id: 453
# Processing match: Pakistan VsZimbabwe with match id: 454
# Processing match: Pakistan VsZimbabwe with match id: 455
# Processing match: India VsSouth Africa with match id: 456
# Processing match: India VsSouth Africa with match id: 457
# Processing match: Zimbabwe VsAfghanistan with match id: 458
# Processing match: Zimbabwe VsAfghanistan with match id: 459
# Processing match: Sri Lanka VsWest Indies with match id: 460
# Processing match: West Indies VsSri Lanka with match id: 461
# Processing match: Zimbabwe VsBangladesh with match id: 462
# Processing match: Bangladesh VsZimbabwe with match id: 463
# Processing match: Hong Kong VsOman with match id: 464
# Processing match: Oman VsUnited Arab Emirates with match id: 465
# Processing match: Oman VsHong Kong with match id: 466
# Processing match: Oman VsHong Kong with match id: 467
# Processing match: England VsPakistan with match id: 468
# Processing match: England VsPakistan with match id: 469
# Processing match: Afghanistan VsHong Kong with match id: 470
# Processing match: Afghanistan VsOman with match id: 471
# Processing match: Afghanistan VsOman with match id: 472
# Processing match: England VsPakistan with match id: 473
# Processing match: New Zealand VsSri Lanka with match id: 474
# Processing match: Afghanistan VsZimbabwe with match id: 475
# Processing match: Sri Lanka VsNew Zealand with match id: 476
# Processing match: Afghanistan VsZimbabwe with match id: 477
# Processing match: Pakistan VsNew Zealand with match id: 478
# Processing match: Zimbabwe VsBangladesh with match id: 479
# Processing match: Pakistan VsNew Zealand with match id: 480
# Processing match: Bangladesh VsZimbabwe with match id: 481
# Processing match: Zimbabwe VsBangladesh with match id: 482
# Processing match: New Zealand VsPakistan with match id: 483
# Processing match: Zimbabwe VsBangladesh with match id: 484
# Processing match: India VsAustralia with match id: 485
# Processing match: India VsAustralia with match id: 486
# Processing match: Scotland VsHong Kong with match id: 487
# Processing match: Scotland VsHong Kong with match id: 488
# Processing match: Australia VsIndia with match id: 489
# Processing match: Netherlands VsUnited Arab Emirates with match id: 490
# Processing match: United Arab Emirates VsScotland with match id: 491
# Processing match: Scotland VsNetherlands with match id: 492
# Processing match: Papua New Guinea VsIreland with match id: 493
# Processing match: Ireland VsPapua New Guinea with match id: 494
# Processing match: Papua New Guinea VsIreland with match id: 495
# Processing match: India VsSri Lanka with match id: 496
# Processing match: India VsSri Lanka with match id: 497
# Processing match: Ireland VsUnited Arab Emirates with match id: 498
# Processing match: Sri Lanka VsIndia with match id: 499
# Processing match: United Arab Emirates VsIreland with match id: 500
# Processing match: United Arab Emirates VsAfghanistan with match id: 501
# Processing match: Oman VsHong Kong with match id: 502
# Processing match: England VsSouth Africa with match id: 503
# Processing match: Oman VsAfghanistan with match id: 504
# Processing match: Hong Kong VsUnited Arab Emirates with match id: 505
# Processing match: England VsSouth Africa with match id: 506
# Processing match: Afghanistan VsHong Kong with match id: 507
# Processing match: United Arab Emirates VsOman with match id: 508
# Processing match: India VsBangladesh with match id: 509
# Processing match: Sri Lanka VsUnited Arab Emirates with match id: 510
# Processing match: Bangladesh VsUnited Arab Emirates with match id: 511
# Processing match: Pakistan VsIndia with match id: 512
# Processing match: Bangladesh VsSri Lanka with match id: 513
# Processing match: United Arab Emirates VsPakistan with match id: 514
# Processing match: Sri Lanka VsIndia with match id: 515
# Processing match: Pakistan VsBangladesh with match id: 516
# Processing match: United Arab Emirates VsIndia with match id: 517
# Processing match: Sri Lanka VsPakistan with match id: 518
# Processing match: Australia VsSouth Africa with match id: 519
# Processing match: South Africa VsAustralia with match id: 520
# Processing match: Bangladesh VsIndia with match id: 521
# Processing match: Zimbabwe VsHong Kong with match id: 522
# Processing match: Afghanistan VsScotland with match id: 523
# Processing match: Bangladesh VsNetherlands with match id: 524
# Processing match: Ireland VsOman with match id: 525
# Processing match: South Africa VsAustralia with match id: 526
# Processing match: Zimbabwe VsScotland with match id: 527
# Processing match: Hong Kong VsAfghanistan with match id: 528
# Processing match: Afghanistan VsZimbabwe with match id: 531
# Processing match: Hong Kong VsScotland with match id: 532
# Processing match: Netherlands VsIreland with match id: 533
# Processing match: Bangladesh VsOman with match id: 534
# Processing match: New Zealand VsIndia with match id: 535
# Processing match: Pakistan VsBangladesh with match id: 536
# Processing match: England VsWest Indies with match id: 537
# Processing match: Afghanistan VsSri Lanka with match id: 538
# Processing match: New Zealand VsAustralia with match id: 539
# Processing match: South Africa VsEngland with match id: 540
# Processing match: Pakistan VsIndia with match id: 541
# Processing match: South Africa VsAfghanistan with match id: 542
# Processing match: Sri Lanka VsWest Indies with match id: 543
# Processing match: Bangladesh VsAustralia with match id: 544
# Processing match: New Zealand VsPakistan with match id: 545
# Processing match: England VsAfghanistan with match id: 546
# Processing match: India VsBangladesh with match id: 547
# Processing match: Australia VsPakistan with match id: 548
# Processing match: South Africa VsWest Indies with match id: 549
# Processing match: New Zealand VsBangladesh with match id: 550
# Processing match: England VsSri Lanka with match id: 551
# Processing match: Afghanistan VsWest Indies with match id: 552
# Processing match: Australia VsIndia with match id: 553
# Processing match: Sri Lanka VsSouth Africa with match id: 554
# Processing match: New Zealand VsEngland with match id: 555
# Processing match: India VsWest Indies with match id: 556
# Processing match: England VsWest Indies with match id: 557
# Processing match: Zimbabwe VsIndia with match id: 558
# Processing match: Zimbabwe VsIndia with match id: 559
# Processing match: India VsZimbabwe with match id: 560
# Processing match: Sri Lanka VsEngland with match id: 561
# Processing match: West Indies VsIndia with match id: 562
# Processing match: Hong Kong VsIreland with match id: 564
# Processing match: Australia VsSri Lanka with match id: 565
# Processing match: England VsPakistan with match id: 566
# Processing match: Sri Lanka VsAustralia with match id: 567
# Processing match: West Indies VsPakistan with match id: 568
# Processing match: Pakistan VsWest Indies with match id: 569
# Processing match: West Indies VsPakistan with match id: 570
# Processing match: Afghanistan VsUnited Arab Emirates with match id: 571
# Processing match: United Arab Emirates VsAfghanistan with match id: 572
# Processing match: Afghanistan VsUnited Arab Emirates with match id: 573
# Processing match: Bangladesh VsNew Zealand with match id: 574
# Processing match: New Zealand VsBangladesh with match id: 575
# Processing match: New Zealand VsBangladesh with match id: 576
# Processing match: Scotland VsHong Kong with match id: 577
# Processing match: Ireland VsAfghanistan with match id: 578
# Processing match: Oman VsNetherlands with match id: 579
# Processing match: Hong Kong VsOman with match id: 580
# Processing match: United Arab Emirates VsAfghanistan with match id: 581
# Processing match: Scotland VsNetherlands with match id: 582
# Processing match: Ireland VsUnited Arab Emirates with match id: 583
# Processing match: Hong Kong VsNetherlands with match id: 584
# Processing match: Oman VsScotland with match id: 585
# Processing match: Oman VsAfghanistan with match id: 586
# Processing match: Ireland VsScotland with match id: 587
# Processing match: Ireland VsAfghanistan with match id: 588
# Processing match: South Africa VsSri Lanka with match id: 589
# Processing match: South Africa VsSri Lanka with match id: 590
# Processing match: South Africa VsSri Lanka with match id: 591
# Processing match: India VsEngland with match id: 592
# Processing match: India VsEngland with match id: 593
# Processing match: India VsEngland with match id: 594
# Processing match: South Africa VsNew Zealand with match id: 595
# Processing match: Australia VsSri Lanka with match id: 596
# Processing match: Australia VsSri Lanka with match id: 597
# Processing match: Australia VsSri Lanka with match id: 598
# Processing match: Ireland VsAfghanistan with match id: 599
# Processing match: Afghanistan VsIreland with match id: 600
# Processing match: Afghanistan VsIreland with match id: 601
# Processing match: West Indies VsPakistan with match id: 602
# Processing match: Pakistan VsWest Indies with match id: 603
# Processing match: Pakistan VsWest Indies with match id: 604
# Processing match: West Indies VsPakistan with match id: 605
# Processing match: Bangladesh VsSri Lanka with match id: 606
# Processing match: Bangladesh VsSri Lanka with match id: 607
# Processing match: Papua New Guinea VsUnited Arab Emirates with match id: 608
# Processing match: United Arab Emirates VsPapua New Guinea with match id: 609
# Processing match: Papua New Guinea VsUnited Arab Emirates with match id: 610
# Processing match: Afghanistan VsWest Indies with match id: 611
# Processing match: West Indies VsAfghanistan with match id: 612
# Processing match: Afghanistan VsWest Indies with match id: 613
# Processing match: South Africa VsEngland with match id: 614
# Processing match: South Africa VsEngland with match id: 615
# Processing match: England VsSouth Africa with match id: 616
# Processing match: India VsWest Indies with match id: 617
# Processing match: Sri Lanka VsIndia with match id: 618
# Processing match: Pakistan VsWorld-XI with match id: 619
# Processing match: Pakistan VsWorld-XI with match id: 620
# Processing match: Pakistan VsWorld-XI with match id: 621
# Processing match: West Indies VsEngland with match id: 622
# Processing match: Australia VsIndia with match id: 623
# Processing match: India VsAustralia with match id: 624
# Processing match: Sri Lanka VsPakistan with match id: 625
# Processing match: South Africa VsBangladesh with match id: 626
# Processing match: Sri Lanka VsPakistan with match id: 627
# Processing match: South Africa VsBangladesh with match id: 628
# Processing match: Pakistan VsSri Lanka with match id: 629
# Processing match: India VsNew Zealand with match id: 630
# Processing match: New Zealand VsIndia with match id: 631
# Processing match: India VsNew Zealand with match id: 632
# Processing match: India VsSri Lanka with match id: 633
# Processing match: India VsSri Lanka with match id: 634
# Processing match: Sri Lanka VsIndia with match id: 635
# Processing match: New Zealand VsWest Indies with match id: 636
# Processing match: New Zealand VsWest Indies with match id: 638
# Processing match: Pakistan VsNew Zealand with match id: 639
# Processing match: Pakistan VsNew Zealand with match id: 640
# Processing match: Pakistan VsNew Zealand with match id: 641
# Processing match: New Zealand VsAustralia with match id: 642
# Processing match: Zimbabwe VsAfghanistan with match id: 643
# Processing match: Afghanistan VsZimbabwe with match id: 644
# Processing match: England VsAustralia with match id: 645
# Processing match: England VsAustralia with match id: 646
# Processing match: New Zealand VsEngland with match id: 647
# Processing match: Bangladesh VsSri Lanka with match id: 648
# Processing match: New Zealand VsAustralia with match id: 649
# Processing match: England VsNew Zealand with match id: 650
# Processing match: Sri Lanka VsBangladesh with match id: 651
# Processing match: India VsSouth Africa with match id: 652
# Processing match: New Zealand VsAustralia with match id: 653
# Processing match: India VsSouth Africa with match id: 654
# Processing match: India VsSouth Africa with match id: 655
# Processing match: India VsSri Lanka with match id: 656
# Processing match: Bangladesh VsIndia with match id: 657
# Processing match: Sri Lanka VsBangladesh with match id: 658
# Processing match: Sri Lanka VsIndia with match id: 659
# Processing match: India VsBangladesh with match id: 660
# Processing match: Sri Lanka VsBangladesh with match id: 661
# Processing match: Bangladesh VsIndia with match id: 662
# Processing match: Pakistan VsWest Indies with match id: 663
# Processing match: Pakistan VsWest Indies with match id: 664
# Processing match: West Indies VsPakistan with match id: 665
# Processing match: West Indies VsICC World XI with match id: 666
# Processing match: Afghanistan VsBangladesh with match id: 667
# Processing match: Bangladesh VsAfghanistan with match id: 668
# Processing match: Afghanistan VsBangladesh with match id: 669
# Processing match: Netherlands VsIreland with match id: 670
# Processing match: Pakistan VsScotland with match id: 671
# Processing match: Ireland VsNetherlands with match id: 672
# Processing match: Pakistan VsScotland with match id: 673
# Processing match: Ireland VsScotland with match id: 674
# Processing match: Scotland VsIreland with match id: 675
# Processing match: Netherlands VsScotland with match id: 676
# Processing match: Scotland VsNetherlands with match id: 677
# Processing match: India VsIreland with match id: 678
# Processing match: England VsAustralia with match id: 679
# Processing match: India VsIreland with match id: 680
# Processing match: Pakistan VsZimbabwe with match id: 681
# Processing match: Pakistan VsAustralia with match id: 682
# Processing match: Australia VsZimbabwe with match id: 683
# Processing match: England VsIndia with match id: 684
# Processing match: Zimbabwe VsPakistan with match id: 685
# Processing match: Pakistan VsAustralia with match id: 686
# Processing match: Zimbabwe VsAustralia with match id: 687
# Processing match: India VsEngland with match id: 688
# Processing match: Australia VsPakistan with match id: 689
# Processing match: England VsIndia with match id: 690
# Processing match: Bangladesh VsWest Indies with match id: 692
# Processing match: Bangladesh VsWest Indies with match id: 693
# Processing match: Bangladesh VsWest Indies with match id: 694
# Processing match: South Africa VsSri Lanka with match id: 695
# Processing match: Afghanistan VsIreland with match id: 696
# Processing match: Afghanistan VsIreland with match id: 697
# Processing match: South Africa VsZimbabwe with match id: 698
# Processing match: Zimbabwe VsSouth Africa with match id: 699
# Processing match: United Arab Emirates VsAustralia with match id: 700
# Processing match: Pakistan VsAustralia with match id: 701
# Processing match: Pakistan VsAustralia with match id: 702
# Processing match: England VsSri Lanka with match id: 703
# Processing match: Pakistan VsAustralia with match id: 704
# Processing match: Pakistan VsNew Zealand with match id: 705
# Processing match: New Zealand VsPakistan with match id: 706
# Processing match: West Indies VsIndia with match id: 707
# Processing match: Pakistan VsNew Zealand with match id: 708
# Processing match: India VsWest Indies with match id: 709
# Processing match: West Indies VsIndia with match id: 710
# Processing match: South Africa VsAustralia with match id: 711
# Processing match: Australia VsIndia with match id: 712
# Processing match: Australia VsIndia with match id: 714
# Processing match: Bangladesh VsWest Indies with match id: 715
# Processing match: Bangladesh VsWest Indies with match id: 716
# Processing match: West Indies VsBangladesh with match id: 717
# Processing match: New Zealand VsSri Lanka with match id: 718
# Processing match: Bahrain VsSaudi Arabia with match id: 719
# Processing match: Maldives VsKuwait with match id: 720
# Processing match: Maldives VsBahrain with match id: 721
# Processing match: Saudi Arabia VsQatar with match id: 722
# Processing match: Qatar VsKuwait with match id: 723
# Processing match: Maldives VsSaudi Arabia with match id: 724
# Processing match: Maldives VsQatar with match id: 725
# Processing match: Bahrain VsKuwait with match id: 726
# Processing match: Kuwait VsSaudi Arabia with match id: 727
# Processing match: Qatar VsBahrain with match id: 728
# Processing match: Qatar VsSaudi Arabia with match id: 729
# Processing match: United Arab Emirates VsNepal with match id: 730
# Processing match: United Arab Emirates VsNepal with match id: 731
# Processing match: South Africa VsPakistan with match id: 732
# Processing match: Nepal VsUnited Arab Emirates with match id: 733
# Processing match: South Africa VsPakistan with match id: 734
# Processing match: New Zealand VsIndia with match id: 735
# Processing match: Pakistan VsSouth Africa with match id: 736
# Processing match: New Zealand VsIndia with match id: 737
# Processing match: New Zealand VsIndia with match id: 738
# Processing match: Scotland VsNetherlands with match id: 739
# Processing match: Ireland VsOman with match id: 740
# Processing match: Oman VsNetherlands with match id: 741
# Processing match: Ireland VsScotland with match id: 742
# Processing match: Netherlands VsIreland with match id: 743
# Processing match: Oman VsScotland with match id: 744
# Processing match: Ireland VsAfghanistan with match id: 745
# Processing match: Afghanistan VsIreland with match id: 746
# Processing match: Afghanistan VsIreland with match id: 747
# Processing match: India VsAustralia with match id: 748
# Processing match: India VsAustralia with match id: 749
# Processing match: West Indies VsEngland with match id: 750
# Processing match: England VsWest Indies with match id: 751
# Processing match: West Indies VsEngland with match id: 752
# Processing match: United Arab Emirates VsUnited States of America with match id: 754
# Processing match: Sri Lanka VsSouth Africa with match id: 755
# Processing match: Papua New Guinea VsPhilippines with match id: 756
# Processing match: Vanuatu VsPapua New Guinea with match id: 757
# Processing match: South Africa VsSri Lanka with match id: 758
# Processing match: Vanuatu VsPhilippines with match id: 759
# Processing match: Philippines VsVanuatu with match id: 761
# Processing match: Vanuatu VsPapua New Guinea with match id: 762
# Processing match: South Africa VsSri Lanka with match id: 763
# Processing match: Malta VsSpain with match id: 764
# Processing match: Spain VsMalta with match id: 765
# Processing match: Mexico VsBelize with match id: 766
# Processing match: Costa Rica VsPanama with match id: 767
# Processing match: Costa Rica VsMexico with match id: 768
# Processing match: Belize VsPanama with match id: 769
# Processing match: Costa Rica VsBelize with match id: 771
# Processing match: Panama VsMexico with match id: 770
# Processing match: Pakistan VsEngland with match id: 772
# Processing match: Germany VsBelgium with match id: 773
# Processing match: Germany VsBelgium with match id: 774
# Processing match: Belgium VsGermany with match id: 775
# Processing match: Nigeria VsKenya with match id: 776
# Processing match: Ghana VsNamibia with match id: 777
# Processing match: Uganda VsBotswana with match id: 778
# Processing match: Namibia VsUganda with match id: 779
# Processing match: Nigeria VsBotswana with match id: 780
# Processing match: Kenya VsGhana with match id: 781
# Processing match: Nigeria VsGhana with match id: 782
# Processing match: Botswana VsNamibia with match id: 783
# Processing match: Kenya VsUganda with match id: 784
# Processing match: Ghana VsUganda with match id: 785
# Processing match: Germany VsItaly with match id: 786
# Processing match: Germany VsItaly with match id: 787
# Processing match: Jersey VsGuernsey with match id: 788
# Processing match: Jersey VsGuernsey with match id: 789
# Processing match: Jersey VsGuernsey with match id: 790
# Processing match: Guernsey VsJersey with match id: 791
# Processing match: Norway VsItaly with match id: 792
# Processing match: Guernsey VsGermany with match id: 793
# Processing match: Germany VsItaly with match id: 794
# Processing match: Jersey VsDenmark with match id: 795
# Processing match: Italy VsGuernsey with match id: 796
# Processing match: Jersey VsNorway with match id: 797
# Processing match: Denmark VsNorway with match id: 798
# Processing match: Norway VsGuernsey with match id: 801
# Processing match: Jersey VsItaly with match id: 802
# Processing match: Denmark VsGermany with match id: 803
# Processing match: Guernsey VsDenmark with match id: 804
# Processing match: Norway VsGermany with match id: 805
# Processing match: Denmark VsItaly with match id: 806
# Processing match: Jersey VsGermany with match id: 807
# Processing match: Netherlands VsZimbabwe with match id: 808
# Processing match: Thailand VsMalaysia with match id: 809
# Processing match: Malaysia VsMaldives with match id: 810
# Processing match: Netherlands VsZimbabwe with match id: 811
# Processing match: Thailand VsMaldives with match id: 812
# Processing match: Thailand VsMalaysia with match id: 813
# Processing match: Maldives VsThailand with match id: 815
# Processing match: Qatar VsKuwait with match id: 816
# Processing match: Kuwait VsQatar with match id: 817
# Processing match: Kuwait VsQatar with match id: 818
# Processing match: Samoa VsPapua New Guinea with match id: 819
# Processing match: Vanuatu VsPapua New Guinea with match id: 820
# Processing match: Vanuatu VsSamoa with match id: 821
# Processing match: Samoa VsPapua New Guinea with match id: 822
# Processing match: Vanuatu VsSamoa with match id: 823
# Processing match: Papua New Guinea VsVanuatu with match id: 824
# Processing match: Zimbabwe VsIreland with match id: 825
# Processing match: Papua New Guinea VsVanuatu with match id: 826
# Processing match: Malaysia VsNepal with match id: 827
# Processing match: Denmark VsFinland with match id: 828
# Processing match: Denmark VsFinland with match id: 829
# Processing match: Nepal VsMalaysia with match id: 830
# Processing match: Ireland VsZimbabwe with match id: 831
# Processing match: Singapore VsQatar with match id: 832
# Processing match: Malaysia VsKuwait with match id: 833
# Processing match: Nepal VsQatar with match id: 834
# Processing match: Malaysia VsNepal with match id: 835
# Processing match: Kuwait VsQatar with match id: 836
# Processing match: Malaysia VsSingapore with match id: 837
# Processing match: Kuwait VsNepal with match id: 838
# Processing match: Malaysia VsQatar with match id: 839
# Processing match: Singapore VsNepal with match id: 840
# Processing match: United Arab Emirates VsNetherlands with match id: 841
# Processing match: West Indies VsIndia with match id: 842
# Processing match: India VsWest Indies with match id: 843
# Processing match: Netherlands VsUnited Arab Emirates with match id: 844
# Processing match: United Arab Emirates VsNetherlands with match id: 845
# Processing match: West Indies VsIndia with match id: 846
# Processing match: Netherlands VsUnited Arab Emirates with match id: 847
# Processing match: Finland VsSpain with match id: 848
# Processing match: Finland VsSpain with match id: 849
# Processing match: Finland VsSpain with match id: 850
# Processing match: Bermuda VsUnited States of America with match id: 851
# Processing match: Canada VsCayman Islands with match id: 852
# Processing match: Namibia VsBotswana with match id: 853
# Processing match: Cayman Islands VsUnited States of America with match id: 855
# Processing match: Namibia VsBotswana with match id: 856
# Processing match: Cayman Islands VsBermuda with match id: 857
# Processing match: United States of America VsCanada with match id: 858
# Processing match: Namibia VsBotswana with match id: 859
# Processing match: Cayman Islands VsCanada with match id: 860
# Processing match: United States of America VsBermuda with match id: 861
# Processing match: Botswana VsNamibia with match id: 862
# Processing match: Cayman Islands VsUnited States of America with match id: 863
# Processing match: Bermuda VsCanada with match id: 864
# Processing match: Canada VsUnited States of America with match id: 865
# Processing match: Cayman Islands VsBermuda with match id: 866
# Processing match: Romania VsAustria with match id: 867
# Processing match: Turkey VsLuxembourg with match id: 868
# Processing match: Romania VsTurkey with match id: 869
# Processing match: Czech Republic VsAustria with match id: 870
# Processing match: Luxembourg VsRomania with match id: 871
# Processing match: Czech Republic VsTurkey with match id: 872
# Processing match: Austria VsLuxembourg with match id: 873
# Processing match: Romania VsCzech Republic with match id: 874
# Processing match: Turkey VsAustria with match id: 875
# Processing match: Luxembourg VsCzech Republic with match id: 876
# Processing match: Austria VsCzech Republic with match id: 877
# Processing match: Sri Lanka VsNew Zealand with match id: 878
# Processing match: Sri Lanka VsNew Zealand with match id: 879
# Processing match: Sri Lanka VsNew Zealand with match id: 880
# Processing match: Zimbabwe VsBangladesh with match id: 881
# Processing match: Afghanistan VsZimbabwe with match id: 882
# Processing match: Afghanistan VsBangladesh with match id: 883
# Processing match: Scotland VsNetherlands with match id: 884
# Processing match: Scotland VsIreland with match id: 885
# Processing match: Bangladesh VsZimbabwe with match id: 886
# Processing match: Ireland VsNetherlands with match id: 887
# Processing match: South Africa VsIndia with match id: 888
# Processing match: Netherlands VsScotland with match id: 889
# Processing match: Afghanistan VsZimbabwe with match id: 890
# Processing match: Ireland VsScotland with match id: 891
# Processing match: Afghanistan VsBangladesh with match id: 892
# Processing match: India VsSouth Africa with match id: 893
# Processing match: Nepal VsZimbabwe with match id: 894
# Processing match: Singapore VsNepal with match id: 895
# Processing match: Vanuatu VsMalaysia with match id: 896
# Processing match: Singapore VsZimbabwe with match id: 897
# Processing match: Vanuatu VsMalaysia with match id: 898
# Processing match: Zimbabwe VsNepal with match id: 899
# Processing match: Malaysia VsVanuatu with match id: 900
# Processing match: Malaysia VsVanuatu with match id: 901
# Processing match: Singapore VsZimbabwe with match id: 902
# Processing match: Mexico VsArgentina with match id: 903
# Processing match: Brazil VsChile with match id: 904
# Processing match: Peru VsBrazil with match id: 905
# Processing match: Malaysia VsVanuatu with match id: 906
# Processing match: Mexico VsChile with match id: 907
# Processing match: Peru VsArgentina with match id: 908
# Processing match: Argentina VsBrazil with match id: 909
# Processing match: Hong Kong VsOman with match id: 910
# Processing match: Netherlands VsIreland with match id: 911
# Processing match: Argentina VsChile with match id: 912
# Processing match: Mexico VsPeru with match id: 913
# Processing match: Sri Lanka VsPakistan with match id: 914
# Processing match: Peru VsChile with match id: 915
# Processing match: Mexico VsBrazil with match id: 916
# Processing match: Oman VsIreland with match id: 917
# Processing match: Hong Kong VsNepal with match id: 918
# Processing match: Mexico VsArgentina with match id: 919
# Processing match: Netherlands VsNepal with match id: 920
# Processing match: Ireland VsHong Kong with match id: 921
# Processing match: Sri Lanka VsPakistan with match id: 922
# Processing match: Ireland VsNepal with match id: 923
# Processing match: Netherlands VsOman with match id: 924
# Processing match: Sri Lanka VsPakistan with match id: 925
# Processing match: Qatar VsJersey with match id: 926
# Processing match: Netherlands VsHong Kong with match id: 927
# Processing match: Nepal VsOman with match id: 928
# Processing match: Jersey VsQatar with match id: 929
# Processing match: Jersey VsQatar with match id: 930
# Processing match: Serbia VsBulgaria with match id: 931
# Processing match: Serbia VsGreece with match id: 932
# Processing match: Bulgaria VsGreece with match id: 933
# Processing match: Czech Republic VsMalta with match id: 934
# Processing match: Singapore VsScotland with match id: 935
# Processing match: Hong Kong VsIreland with match id: 936
# Processing match: Netherlands VsKenya with match id: 937
# Processing match: Bulgaria VsGreece with match id: 938
# Processing match: United Arab Emirates VsOman with match id: 939
# Processing match: Bermuda VsPapua New Guinea with match id: 940
# Processing match: Jersey VsNigeria with match id: 941
# Processing match: Netherlands VsNamibia with match id: 942
# Processing match: Scotland VsKenya with match id: 943
# Processing match: Ireland VsUnited Arab Emirates with match id: 944
# Processing match: Czech Republic VsMalta with match id: 945
# Processing match: Papua New Guinea VsNamibia with match id: 946
# Processing match: Canada VsJersey with match id: 947
# Processing match: Bermuda VsSingapore with match id: 948
# Processing match: Hong Kong VsOman with match id: 949
# Processing match: Scotland VsPapua New Guinea with match id: 950
# Processing match: Hong Kong VsUnited Arab Emirates with match id: 951
# Processing match: Ireland VsOman with match id: 952
# Processing match: Kenya VsBermuda with match id: 953
# Processing match: Canada VsNigeria with match id: 954
# Processing match: Namibia VsScotland with match id: 955
# Processing match: Singapore VsNetherlands with match id: 956
# Processing match: Jersey VsUnited Arab Emirates with match id: 957
# Processing match: Bermuda VsNamibia with match id: 958
# Processing match: Nigeria VsOman with match id: 959
# Processing match: Singapore VsKenya with match id: 960
# Processing match: Canada VsIreland with match id: 961
# Processing match: Hong Kong VsJersey with match id: 962
# Processing match: Netherlands VsPapua New Guinea with match id: 963
# Processing match: Nigeria VsUnited Arab Emirates with match id: 964
# Processing match: Hong Kong VsCanada with match id: 965
# Processing match: Scotland VsBermuda with match id: 966
# Processing match: Papua New Guinea VsSingapore with match id: 967
# Processing match: Jersey VsIreland with match id: 968
# Processing match: Namibia VsKenya with match id: 969
# Processing match: Portugal VsSpain with match id: 970
# Processing match: Canada VsOman with match id: 971
# Processing match: Nigeria VsIreland with match id: 972
# Processing match: Gibraltar VsPortugal with match id: 973
# Processing match: Netherlands VsBermuda with match id: 974
# Processing match: Gibraltar VsSpain with match id: 975
# Processing match: Spain VsPortugal with match id: 976
# Processing match: Namibia VsSingapore with match id: 977
# Processing match: Australia VsSri Lanka with match id: 978
# Processing match: Papua New Guinea VsKenya with match id: 979
# Processing match: Nigeria VsHong Kong with match id: 980
# Processing match: Gibraltar VsPortugal with match id: 981
# Processing match: Jersey VsOman with match id: 982
# Processing match: Scotland VsNetherlands with match id: 983
# Processing match: Gibraltar VsSpain with match id: 984
# Processing match: United Arab Emirates VsCanada with match id: 985
# Processing match: United Arab Emirates VsNetherlands with match id: 986
# Processing match: Namibia VsOman with match id: 987
# Processing match: Sri Lanka VsAustralia with match id: 988
# Processing match: Scotland VsUnited Arab Emirates with match id: 989
# Processing match: Oman VsHong Kong with match id: 990
# Processing match: Oman VsScotland with match id: 991
# Processing match: New Zealand VsEngland with match id: 992
# Processing match: Sri Lanka VsAustralia with match id: 993
# Processing match: Netherlands VsIreland with match id: 994
# Processing match: Papua New Guinea VsNamibia with match id: 995
# Processing match: Ireland VsNamibia with match id: 996
# Processing match: Papua New Guinea VsNetherlands with match id: 997
# Processing match: New Zealand VsEngland with match id: 998
# Processing match: India VsBangladesh with match id: 1000
# Processing match: New Zealand VsEngland with match id: 1001
# Processing match: Pakistan VsAustralia with match id: 1002
# Processing match: Mozambique VsMalawi with match id: 1003
# Processing match: Mozambique VsMalawi with match id: 1004
# Processing match: Malawi VsMozambique with match id: 1005
# Processing match: Mozambique VsMalawi with match id: 1006
# Processing match: Bangladesh VsIndia with match id: 1007
# Processing match: England VsNew Zealand with match id: 1008
# Processing match: Pakistan VsAustralia with match id: 1009
# Processing match: Malawi VsMozambique with match id: 1010
# Processing match: New Zealand VsEngland with match id: 1012
# Processing match: Mozambique VsMalawi with match id: 1013
# Processing match: India VsBangladesh with match id: 1014
# Processing match: West Indies VsAfghanistan with match id: 1015
# Processing match: Afghanistan VsWest Indies with match id: 1016
# Processing match: Afghanistan VsWest Indies with match id: 1017
# Processing match: Nepal VsBhutan with match id: 1018
# Processing match: Nepal VsMaldives with match id: 1019
# Processing match: West Indies VsIndia with match id: 1020
# Processing match: Bhutan VsMaldives with match id: 1021
# Processing match: India VsWest Indies with match id: 1022
# Processing match: Maldives VsNepal with match id: 1023
# Processing match: India VsWest Indies with match id: 1024

# %%
combined_t20_batting_df.head()
# Out:
#               Match Name  teamInnings  Batting Position        Batsman Name  \
# 0  Afghanistan VsIreland  Afghanistan                 1         Karim Sadiq
# 1  Afghanistan VsIreland  Afghanistan                 2         Shafiqullah
# 2  Afghanistan VsIreland  Afghanistan                 3  Mohammad Shahzad †
# 3  Afghanistan VsIreland  Afghanistan                 4   Nawroz Mangal (c)
# 4  Afghanistan VsIreland  Afghanistan                 5       Asghar Afghan
#
#                    Dismissal Runs Balls   M 4s 6s Match id Strike Rate
# 0  st †NJ O'Brien b Johnston    3     6  10  0  0      128       50.00
# 1             lbw b Johnston   23    16  27  3  1      128      143.75
# 2    c KJ O'Brien b Johnston   10     8   8  2  0      128      125.00
# 3        c Wilson b Dockrell   27    25  31  5  0      128      108.00
# 4         c White b Johnston    1     5   7  0  0      128       20.00

# %%
test_matches_df.head()
# Out:
#                      Match        Team 1    Team 2        Winner  \
# 0    Australia vs Pakistan     Australia  Pakistan     Australia
# 1  South Africa vs England  South Africa   England         drawn
# 2    Australia vs Pakistan     Australia  Pakistan     Australia
# 3  South Africa vs England  South Africa   England  South Africa
# 4      Bangladesh vs India    Bangladesh     India         India
#
#            Margin        Ground       Match Date     Match id
# 0         36 runs        Sydney    Jan 3-6, 2010  Test # 1945
# 1                     Cape Town    Jan 3-7, 2010  Test # 1946
# 2        231 runs        Hobart  Jan 14-18, 2010  Test # 1947
# 3  inns & 74 runs  Johannesburg  Jan 14-17, 2010  Test # 1948
# 4        113 runs    Chattogram  Jan 17-21, 2010  Test # 1949

# %%
test_matches_link[14]
# Out:
# 'https://stats.espncricinfo.com/ci/engine/match/426402.html'

# %% [markdown]
# # Extract the batting and bowling stats for test matches

# %%
def scrap_test_matches_scorecards(matches_url):
    batting_dfs = []  # list of dataframes for batting tables
    bowling_dfs = []
    html_content = requests.get(matches_url)
    soup = BeautifulSoup(html_content.content,"html.parser")
    div_info = soup.find_all("div",class_ = "ds-w-full ds-bg-fill-content-prime ds-overflow-hidden ds-rounded-xl ds-border ds-border-line ds-mb-4")
    match_number = []
    for div in div_info:
        tbodys = div.find_all("tbody")
        if tbodys:
            for tbody in tbodys:
                trs = tbody.find_all("tr")
                for tr in trs:
                    td = tr.find_all("td")
                    if len(td) == 2:
                        if td[0].text == "Match number":
                            match_number.append(td[1].text)
#     print(match_number)
    for div in div_info:
        batting_tables = div.find_all("table",class_ = "ds-w-full ds-table ds-table-md ds-table-auto ci-scorecard-table")
        bowling_tables = div.find_all("table",class_ = "ds-w-full ds-table ds-table-md ds-table-auto")
        inningsTeam = div.find_all("span",class_ = "ds-text-title-xs ds-font-bold ds-capitalize")
        innings_team_names = []
        for team in inningsTeam:
            team_name = team.text.strip()
            if team_name:
                innings_team_names.append(team_name)
        if batting_tables:
            innings_batting_dfs = []  # list of dataframes for innings batting data
            for table in batting_tables:
                innings_team_name = inningsTeam.pop().text
                batting_columns = []
                for th in table.find("thead").find_all('th'):
                    batting_columns.append(th.text.strip())
                batting_data = []
                for tr in table.find("tbody").find_all('tr'):
                    batting_row = []
                    for td in tr.find_all("td"):
                        batting_row.append(td.text.strip())
                    if any(batting_row):
                        batting_data.append(batting_row)
                batting_columns = ['Batsman Name','Dismissal','Runs','Balls','M','4s','6s','Strike Rate']
                innings_batting_df = pd.DataFrame(batting_data, columns=batting_columns)
                innings_batting_df = innings_batting_df[~innings_batting_df['Batsman Name'].str.contains('Extras|TOTAL|Did not bat|Fall of wickets')]
                innings_batting_df['Match Number'] = match_number[0]
                innings_batting_dfs.append(innings_batting_df)
                innings_batting_df.insert(0, "teamInnings", innings_team_name)
                innings_batting_df.insert(1, "Batting Position", range(1, 1+len(innings_batting_df)))
            innings_batting_df = pd.concat(innings_batting_dfs, ignore_index=True)  # concatenate all innings batting dataframes
            batting_dfs.append(innings_batting_df)
        if bowling_tables:
            innings_bowling_dfs = []
            for table in bowling_tables:
#                 inningsteam_name = inningsTeam.pop().text
                bowling_columns = []
                for th in table.find("thead").find_all('th'):
                    batting_columns.append(th.text.strip())
                bowling_data = []
                for tr in table.find("tbody").find_all('tr'):
                    bowling_row = []
                    for td in tr.find_all("td"):
                        bowling_row.append(td.text.strip())
                    if len(bowling_row)!=1:
                        bowling_data.append(bowling_row)
                bowling_columns = ['Bowler Name','Over','Maiden','Runs','Wickets','Economy','dots','fours','sixes','wides','no balls']
                innings_bowling_df = pd.DataFrame(bowling_data, columns=bowling_columns)
                innings_bowling_df['Match Number'] = match_number[0]
                innings_bowling_team_name = list(filter(None, innings_team_names))
                if innings_bowling_team_name:
                    innings_bowling_df.insert(0, "teamInnings", innings_bowling_team_name[0])
                innings_bowling_dfs.append(innings_bowling_df)
            innings_bowling_dfs = pd.concat(innings_batting_dfs, ignore_index=True)  # concatenate all innings batting dataframes
            bowling_dfs.append(innings_bowling_df) 
    print(f"Processing match :{match_number[0]}")
    return pd.concat(batting_dfs, ignore_index=True),pd.concat(bowling_dfs, ignore_index=True)  # concatenate all batting dataframes

# %%
scrap_test_matches_scorecards("https://stats.espncricinfo.com/ci/engine/match/426402.html")
# Out:
# Processing match :Test no. 1959
# (   teamInnings  Batting Position         Batsman Name  \
#  0      England                 1   Andrew Strauss (c)
#  1      England                 2        Alastair Cook
#  2      England                 3       Jonathan Trott
#  3      England                 4      Kevin Pietersen
#  4      England                 5             Ian Bell
#  5      England                 6          Eoin Morgan
#  6      England                 7         Matt Prior †
#  7      England                 8         Graeme Swann
#  8      England                 9        Ajmal Shahzad
#  9      England                10       James Anderson
#  10     England                11          Steven Finn
#  11  Bangladesh                 1          Tamim Iqbal
#  12  Bangladesh                 2          Imrul Kayes
#  13  Bangladesh                 3      Junaid Siddique
#  14  Bangladesh                 4        Jahurul Islam
#  15  Bangladesh                 5    Mohammad Ashraful
#  16  Bangladesh                 6  Shakib Al Hasan (c)
#  17  Bangladesh                 7    Mushfiqur Rahim †
#  18  Bangladesh                 8          Mahmudullah
#  19  Bangladesh                 9        Shafiul Islam
#  20  Bangladesh                10         Abdur Razzak
#  21  Bangladesh                11     Shahadat Hossain
#  22  Bangladesh                 1          Tamim Iqbal
#  23  Bangladesh                 2          Imrul Kayes
#  24  Bangladesh                 3      Junaid Siddique
#  25  Bangladesh                 4    Mohammad Ashraful
#  26  Bangladesh                 5        Jahurul Islam
#  27  Bangladesh                 6  Shakib Al Hasan (c)
#  28  Bangladesh                 7    Mushfiqur Rahim †
#  29  Bangladesh                 8          Mahmudullah
#  30  Bangladesh                 9         Abdur Razzak
#  31  Bangladesh                10        Shafiul Islam
#  32  Bangladesh                11     Shahadat Hossain
#
#                                  Dismissal Runs Balls    M  4s 6s Strike Rate  \
#  0           c Imrul Kayes b Shafiul Islam   21    45   46   4  0       46.66
#  1        c Junaid Siddique b Abdur Razzak   29    57  105   4  0       50.87
#  2                         b Shafiul Islam    3     5    8   0  0       60.00
#  3   st †Mushfiqur Rahim b Shakib Al Hasan   64    81  109   7  1       79.01
#  4                       b Shakib Al Hasan  128   255  330  12  1       50.19
#  5      c Jahurul Islam b Shahadat Hossain   37    70   87   4  0       52.85
#  6       c Jahurul Islam b Shakib Al Hasan   93   170  222   9  0       54.70
#  7                      lbw b Abdur Razzak   20    17   15   3  0      117.64
#  8        c Abdur Razzak b Shakib Al Hasan    5    12   14   1  0       41.66
#  9                                 not out    2    17   15   0  0       11.76
#  10                  lbw b Shakib Al Hasan    0     2    1   0  0        0.00
#  11                    c †Prior b Anderson  108   114  150  11  1       94.73
#  12                       c Shahzad b Finn   36    71  103   4  0       50.70
#  13                       c †Prior b Swann    1    13   29   0  0        7.69
#  14                                b Swann    5    14   24   1  0       35.71
#  15                     c Morgan b Shahzad   11    45   55   1  0       24.44
#  16                     c Anderson b Swann   10    20   25   2  0       50.00
#  17                     c Anderson b Swann   11    23   44   1  0       47.82
#  18                              b Shahzad    8    10    8   1  0       80.00
#  19                              b Shahzad    4     9    8   1  0       44.44
#  20                                not out    0     7   11   0  0        0.00
#  21                            lbw b Swann    0     2    5   0  0        0.00
#  22                    c †Prior b Anderson    2     2    1   0  0      100.00
#  23                       c Shahzad b Finn    9    17   27   2  0       52.94
#  24                 c Pietersen b Anderson    6    22   29   1  0       27.27
#  25                     c Trott b Anderson   14    14   31   2  0      100.00
#  26                        c †Prior b Finn    0     6    6   0  0        0.00
#  27                              b Shahzad    1    16   25   0  0        6.25
#  28                c sub (KR Brown) b Finn   13    42   59   2  0       30.95
#  29                        c †Prior b Finn   38    52   73   5  0       73.07
#  30                       c Morgan b Swann   19    22   40   2  1       86.36
#  31                       c Strauss b Finn    4     9   13   0  0       44.44
#  32                                not out    4     3    4   1  0      133.33
#
#       Match Number
#  0   Test no. 1959
#  1   Test no. 1959
#  2   Test no. 1959
#  3   Test no. 1959
#  4   Test no. 1959
#  5   Test no. 1959
#  6   Test no. 1959
#  7   Test no. 1959
#  8   Test no. 1959
#  9   Test no. 1959
#  10  Test no. 1959
#  11  Test no. 1959
#  12  Test no. 1959
#  13  Test no. 1959
#  14  Test no. 1959
#  15  Test no. 1959
#  16  Test no. 1959
#  17  Test no. 1959
#  18  Test no. 1959
#  19  Test no. 1959
#  20  Test no. 1959
#  21  Test no. 1959
#  22  Test no. 1959
#  23  Test no. 1959
#  24  Test no. 1959
#  25  Test no. 1959
#  26  Test no. 1959
#  27  Test no. 1959
#  28  Test no. 1959
#  29  Test no. 1959
#  30  Test no. 1959
#  31  Test no. 1959
#  32  Test no. 1959  ,
#     teamInnings       Bowler Name  Over Maiden Runs Wickets Economy dots fours  \
#  0      England  Shahadat Hossain    21      3   84       1    4.00   88    12
#  1      England     Shafiul Islam    21      2   63       2    3.00   94     7
#  2      England       Mahmudullah    12      1   31       0    2.58   48     1
#  3      England   Shakib Al Hasan  37.3      4  121       5    3.22  150    10
#  4      England      Abdur Razzak    30      3  109       2    3.63  130    14
#  5   Bangladesh    James Anderson    14      4   45       1    3.21   66     6
#  6   Bangladesh       Steven Finn     8      1   39       1    4.87   33     4
#  7   Bangladesh      Graeme Swann  22.1      4   76       5    3.42   92     7
#  8   Bangladesh     Ajmal Shahzad    10      2   45       3    4.50   39     5
#  9   Bangladesh    James Anderson    10      3   16       3    1.60   52     2
#  10  Bangladesh       Steven Finn    10      2   42       5    4.20   46     8
#  11  Bangladesh     Ajmal Shahzad     7      2   18       1    2.57   33     3
#  12  Bangladesh      Graeme Swann   7.1      0   34       1    4.74   27     2
#
#     sixes wides no balls   Match Number
#  0      0     3        2  Test no. 1959
#  1      0     1        0  Test no. 1959
#  2      0     0        0  Test no. 1959
#  3      0     0        0  Test no. 1959
#  4      2     0        0  Test no. 1959
#  5      0     0        2  Test no. 1959
#  6      0     3        1  Test no. 1959
#  7      1     0        0  Test no. 1959
#  8      0     1        0  Test no. 1959
#  9      0     0        0  Test no. 1959
#  10     0     0        0  Test no. 1959
#  11     0     0        0  Test no. 1959
#  12     1     0        0  Test no. 1959  )

# %%
combined_test_batting_df = pd.DataFrame()
combined_test_bowling_df = pd.DataFrame()

# Loop through the match URLs
for match_url in test_matches_link:
    batting_df, bowling_df = scrap_test_matches_scorecards(match_url)
    combined_test_batting_df = combined_test_batting_df.append(batting_df)
    combined_test_bowling_df = combined_test_bowling_df.append(bowling_df)

# Write the combined batting and bowling dataframes to CSV files
combined_test_batting_df.to_csv('test_batting_data.csv', index=False)
combined_test_bowling_df.to_csv('test_bowling_data.csv', index=False)
# Out:
# Processing match :Test no. 1945
# Processing match :Test no. 1946
# Processing match :Test no. 1947
# Processing match :Test no. 1948
# Processing match :Test no. 1949
# Processing match :Test no. 1950
# Processing match :Test no. 1951
# Processing match :Test no. 1952
# Processing match :Test no. 1953
# Processing match :Test no. 1954
# Processing match :Test no. 1955
# Processing match :Test no. 1956
# Processing match :Test no. 1957
# Processing match :Test no. 1958
# Processing match :Test no. 1959
# Processing match :Test no. 1960
# Processing match :Test no. 1961
# Processing match :Test no. 1962
# Processing match :Test no. 1963
# Processing match :Test no. 1964
# Processing match :Test no. 1965
# Processing match :Test no. 1966
# Processing match :Test no. 1967
# Processing match :Test no. 1968
# Processing match :Test no. 1969
# Processing match :Test no. 1970
# Processing match :Test no. 1971
# Processing match :Test no. 1972
# Processing match :Test no. 1973
# Processing match :Test no. 1974
# Processing match :Test no. 1975
# Processing match :Test no. 1976
# Processing match :Test no. 1977
# Processing match :Test no. 1978
# Processing match :Test no. 1979
# Processing match :Test no. 1980
# Processing match :Test no. 1981
# Processing match :Test no. 1982
# Processing match :Test no. 1983
# Processing match :Test no. 1984
# Processing match :Test no. 1985
# Processing match :Test no. 1986
# Processing match :Test no. 1987
# Processing match :Test no. 1988
# Processing match :Test no. 1989
# Processing match :Test no. 1990
# Processing match :Test no. 1991
# Processing match :Test no. 1992
# Processing match :Test no. 1993
# Processing match :Test no. 1994
# Processing match :Test no. 1995
# Processing match :Test no. 1996
# Processing match :Test no. 1997
# Processing match :Test no. 1998
# Processing match :Test no. 1999
# Processing match :Test no. 2000
# Processing match :Test no. 2001
# Processing match :Test no. 2002
# Processing match :Test no. 2003
# Processing match :Test no. 2004
# Processing match :Test no. 2005
# Processing match :Test no. 2006
# Processing match :Test no. 2007
# Processing match :Test no. 2008
# Processing match :Test no. 2009
# Processing match :Test no. 2010
# Processing match :Test no. 2011
# Processing match :Test no. 2012
# Processing match :Test no. 2013
# Processing match :Test no. 2014
# Processing match :Test no. 2015
# Processing match :Test no. 2016
# Processing match :Test no. 2017
# Processing match :Test no. 2018
# Processing match :Test no. 2019
# Processing match :Test no. 2020
# Processing match :Test no. 2021
# Processing match :Test no. 2022
# Processing match :Test no. 2023
# Processing match :Test no. 2024
# Processing match :Test no. 2025
# Processing match :Test no. 2026
# Processing match :Test no. 2027
# Processing match :Test no. 2028
# Processing match :Test no. 2029
# Processing match :Test no. 2030
# Processing match :Test no. 2031
# Processing match :Test no. 2032
# Processing match :Test no. 2033
# Processing match :Test no. 2034
# Processing match :Test no. 2035
# Processing match :Test no. 2036
# Processing match :Test no. 2037
# Processing match :Test no. 2038
# Processing match :Test no. 2039
# Processing match :Test no. 2040
# Processing match :Test no. 2041
# Processing match :Test no. 2042
# Processing match :Test no. 2043
# Processing match :Test no. 2044
# Processing match :Test no. 2045
# Processing match :Test no. 2046
# Processing match :Test no. 2047
# Processing match :Test no. 2048
# Processing match :Test no. 2049
# Processing match :Test no. 2050
# Processing match :Test no. 2051
# Processing match :Test no. 2052
# Processing match :Test no. 2053
# Processing match :Test no. 2054
# Processing match :Test no. 2055
# Processing match :Test no. 2056
# Processing match :Test no. 2057
# Processing match :Test no. 2058
# Processing match :Test no. 2059
# Processing match :Test no. 2060
# Processing match :Test no. 2061
# Processing match :Test no. 2062
# Processing match :Test no. 2063
# Processing match :Test no. 2064
# Processing match :Test no. 2065
# Processing match :Test no. 2066
# Processing match :Test no. 2067
# Processing match :Test no. 2068
# Processing match :Test no. 2069
# Processing match :Test no. 2070
# Processing match :Test no. 2071
# Processing match :Test no. 2072
# Processing match :Test no. 2073
# Processing match :Test no. 2074
# Processing match :Test no. 2075
# Processing match :Test no. 2076
# Processing match :Test no. 2077
# Processing match :Test no. 2078
# Processing match :Test no. 2079
# Processing match :Test no. 2080
# Processing match :Test no. 2081
# Processing match :Test no. 2082
# Processing match :Test no. 2083
# Processing match :Test no. 2084
# Processing match :Test no. 2085
# Processing match :Test no. 2086
# Processing match :Test no. 2087
# Processing match :Test no. 2088
# Processing match :Test no. 2089
# Processing match :Test no. 2090
# Processing match :Test no. 2091
# Processing match :Test no. 2092
# Processing match :Test no. 2093
# Processing match :Test no. 2094
# Processing match :Test no. 2095
# Processing match :Test no. 2096
# Processing match :Test no. 2097
# Processing match :Test no. 2098
# Processing match :Test no. 2099
# Processing match :Test no. 2100
# Processing match :Test no. 2101
# Processing match :Test no. 2102
# Processing match :Test no. 2103
# Processing match :Test no. 2104
# Processing match :Test no. 2105
# Processing match :Test no. 2106
# Processing match :Test no. 2107
# Processing match :Test no. 2108
# Processing match :Test no. 2109
# Processing match :Test no. 2110
# Processing match :Test no. 2111
# Processing match :Test no. 2112
# Processing match :Test no. 2112
# Processing match :Test no. 2113
# Processing match :Test no. 2114
# Processing match :Test no. 2115
# Processing match :Test no. 2116
# Processing match :Test no. 2117
# Processing match :Test no. 2118
# Processing match :Test no. 2119
# Processing match :Test no. 2120
# Processing match :Test no. 2121
# Processing match :Test no. 2122
# Processing match :Test no. 2123
# Processing match :Test no. 2124
# Processing match :Test no. 2125
# Processing match :Test no. 2126
# Processing match :Test no. 2127
# Processing match :Test no. 2128
# Processing match :Test no. 2129
# Processing match :Test no. 2130
# Processing match :Test no. 2131
# Processing match :Test no. 2132
# Processing match :Test no. 2133
# Processing match :Test no. 2134
# Processing match :Test no. 2135
# Processing match :Test no. 2136
# Processing match :Test no. 2137
# Processing match :Test no. 2138
# Processing match :Test no. 2139
# Processing match :Test no. 2140
# Processing match :Test no. 2141
# Processing match :Test no. 2142
# Processing match :Test no. 2143
# Processing match :Test no. 2144
# Processing match :Test no. 2145
# Processing match :Test no. 2146
# Processing match :Test no. 2147
# Processing match :Test no. 2148
# Processing match :Test no. 2149
# Processing match :Test no. 2150
# Processing match :Test no. 2151
# Processing match :Test no. 2152
# Processing match :Test no. 2153
# Processing match :Test no. 2154
# Processing match :Test no. 2155
# Processing match :Test no. 2156
# Processing match :Test no. 2157
# Processing match :Test no. 2158
# Processing match :Test no. 2159
# Processing match :Test no. 2160
# Processing match :Test no. 2161
# Processing match :Test no. 2162
# Processing match :Test no. 2163
# Processing match :Test no. 2164
# Processing match :Test no. 2165
# Processing match :Test no. 2166
# Processing match :Test no. 2167
# Processing match :Test no. 2168
# Processing match :Test no. 2169
# Processing match :Test no. 2170
# Processing match :Test no. 2171
# Processing match :Test no. 2172
# Processing match :Test no. 2173
# Processing match :Test no. 2174
# Processing match :Test no. 2175
# Processing match :Test no. 2176
# Processing match :Test no. 2177
# Processing match :Test no. 2178
# Processing match :Test no. 2179
# Processing match :Test no. 2180
# Processing match :Test no. 2181
# Processing match :Test no. 2182
# Processing match :Test no. 2183
# Processing match :Test no. 2184
# Processing match :Test no. 2185
# Processing match :Test no. 2186
# Processing match :Test no. 2187
# Processing match :Test no. 2188
# Processing match :Test no. 2189
# Processing match :Test no. 2190
# Processing match :Test no. 2191
# Processing match :Test no. 2192
# Processing match :Test no. 2193
# Processing match :Test no. 2194
# Processing match :Test no. 2195
# Processing match :Test no. 2196
# Processing match :Test no. 2197
# Processing match :Test no. 2198
# Processing match :Test no. 2199
# Processing match :Test no. 2200
# Processing match :Test no. 2201
# Processing match :Test no. 2202
# Processing match :Test no. 2203
# Processing match :Test no. 2204
# Processing match :Test no. 2205
# Processing match :Test no. 2206
# Processing match :Test no. 2207
# Processing match :Test no. 2208
# Processing match :Test no. 2209
# Processing match :Test no. 2210
# Processing match :Test no. 2211
# Processing match :Test no. 2212
# Processing match :Test no. 2213
# Processing match :Test no. 2214
# Processing match :Test no. 2215
# Processing match :Test no. 2216
# Processing match :Test no. 2217
# Processing match :Test no. 2218
# Processing match :Test no. 2219
# Processing match :Test no. 2220
# Processing match :Test no. 2221
# Processing match :Test no. 2222
# Processing match :Test no. 2223
# Processing match :Test no. 2224
# Processing match :Test no. 2225
# Processing match :Test no. 2226
# Processing match :Test no. 2227
# Processing match :Test no. 2228
# Processing match :Test no. 2229
# Processing match :Test no. 2230
# Processing match :Test no. 2231
# Processing match :Test no. 2232
# Processing match :Test no. 2233
# Processing match :Test no. 2234
# Processing match :Test no. 2235
# Processing match :Test no. 2236
# Processing match :Test no. 2237
# Processing match :Test no. 2238
# Processing match :Test no. 2239
# Processing match :Test no. 2240
# Processing match :Test no. 2241
# Processing match :Test no. 2242
# Processing match :Test no. 2243
# Processing match :Test no. 2244
# Processing match :Test no. 2245
# Processing match :Test no. 2246
# Processing match :Test no. 2247
# Processing match :Test no. 2248
# Processing match :Test no. 2249
# Processing match :Test no. 2250
# Processing match :Test no. 2251
# Processing match :Test no. 2252
# Processing match :Test no. 2253
# Processing match :Test no. 2254
# Processing match :Test no. 2255
# Processing match :Test no. 2256
# Processing match :Test no. 2257
# Processing match :Test no. 2258
# Processing match :Test no. 2259
# Processing match :Test no. 2260
# Processing match :Test no. 2261
# Processing match :Test no. 2262
# Processing match :Test no. 2263
# Processing match :Test no. 2264
# Processing match :Test no. 2265
# Processing match :Test no. 2266
# Processing match :Test no. 2267
# Processing match :Test no. 2268
# Processing match :Test no. 2269
# Processing match :Test no. 2270
# Processing match :Test no. 2271
# Processing match :Test no. 2272
# Processing match :Test no. 2273
# Processing match :Test no. 2274
# Processing match :Test no. 2275
# Processing match :Test no. 2276
# Processing match :Test no. 2277
# Processing match :Test no. 2278
# Processing match :Test no. 2279
# Processing match :Test no. 2280
# Processing match :Test no. 2281
# Processing match :Test no. 2282
# Processing match :Test no. 2283
# Processing match :Test no. 2284
# Processing match :Test no. 2285
# Processing match :Test no. 2286
# Processing match :Test no. 2287
# Processing match :Test no. 2288
# Processing match :Test no. 2289
# Processing match :Test no. 2290
# Processing match :Test no. 2291
# Processing match :Test no. 2292
# Processing match :Test no. 2293
# Processing match :Test no. 2294
# Processing match :Test no. 2295
# Processing match :Test no. 2296
# Processing match :Test no. 2297
# Processing match :Test no. 2298
# Processing match :Test no. 2299
# Processing match :Test no. 2300
# Processing match :Test no. 2301
# Processing match :Test no. 2302
# Processing match :Test no. 2303
# Processing match :Test no. 2304
# Processing match :Test no. 2305
# Processing match :Test no. 2306
# Processing match :Test no. 2307
# Processing match :Test no. 2308
# Processing match :Test no. 2309
# Processing match :Test no. 2310
# Processing match :Test no. 2311
# Processing match :Test no. 2312
# Processing match :Test no. 2313
# Processing match :Test no. 2314
# Processing match :Test no. 2315
# Processing match :Test no. 2316
# Processing match :Test no. 2317
# Processing match :Test no. 2318
# Processing match :Test no. 2319
# Processing match :Test no. 2320
# Processing match :Test no. 2321
# Processing match :Test no. 2322
# Processing match :Test no. 2323
# Processing match :Test no. 2324
# Processing match :Test no. 2325
# Processing match :Test no. 2326
# Processing match :Test no. 2327
# Processing match :Test no. 2328
# Processing match :Test no. 2329
# Processing match :Test no. 2330
# Processing match :Test no. 2331
# Processing match :Test no. 2332
# Processing match :Test no. 2333
# Processing match :Test no. 2334
# Processing match :Test no. 2335
# Processing match :Test no. 2336
# Processing match :Test no. 2337
# Processing match :Test no. 2338
# Processing match :Test no. 2339
# Processing match :Test no. 2340
# Processing match :Test no. 2341
# Processing match :Test no. 2342
# Processing match :Test no. 2343
# Processing match :Test no. 2344
# Processing match :Test no. 2345
# Processing match :Test no. 2346
# Processing match :Test no. 2347
# Processing match :Test no. 2348
# Processing match :Test no. 2349
# Processing match :Test no. 2350
# Processing match :Test no. 2351
# Processing match :Test no. 2352
# Processing match :Test no. 2353
# Processing match :Test no. 2354
# Processing match :Test no. 2355
# Processing match :Test no. 2356
# Processing match :Test no. 2357
# Processing match :Test no. 2358
# Processing match :Test no. 2359
# Processing match :Test no. 2360
# Processing match :Test no. 2361
# Processing match :Test no. 2362
# Processing match :Test no. 2363
# Processing match :Test no. 2364
# Processing match :Test no. 2365
# Processing match :Test no. 2366
# Processing match :Test no. 2367
# Processing match :Test no. 2368
# Processing match :Test no. 2369
# Processing match :Test no. 2370
# Processing match :Test no. 2371
# Processing match :Test no. 2372
# Processing match :Test no. 2373
# Processing match :Test no. 2374
# Processing match :Test no. 2375
# Processing match :Test no. 2376
# Processing match :Test no. 2377

# %% [markdown]
# # Edit the bowling data of test

# %%
test_info_df = pd.read_csv("test_matches_info.csv")
test_info_df['Match id'] = test_info_df['Match id'].str.replace("Test #","").str.strip()
test_info_df.head()
# Out:
#                      Match        Team 1    Team 2        Winner  \
# 0    Australia vs Pakistan     Australia  Pakistan     Australia
# 1  South Africa vs England  South Africa   England         drawn
# 2    Australia vs Pakistan     Australia  Pakistan     Australia
# 3  South Africa vs England  South Africa   England  South Africa
# 4      Bangladesh vs India    Bangladesh     India         India
#
#            Margin        Ground       Match Date Match id
# 0         36 runs        Sydney    Jan 3-6, 2010     1945
# 1             NaN     Cape Town    Jan 3-7, 2010     1946
# 2        231 runs        Hobart  Jan 14-18, 2010     1947
# 3  inns & 74 runs  Johannesburg  Jan 14-17, 2010     1948
# 4        113 runs    Chattogram  Jan 17-21, 2010     1949

# %%
test_matches_link[0]
# Out:
# 'https://stats.espncricinfo.com/ci/engine/match/406200.html'

# %%
bowling_df = pd.read_csv("test_bowling_data.csv")
bowling_df.head()
# Out:
#   teamInnings     Bowler Name  Over  Maiden  Runs  Wickets  Economy  dots  \
# 0   Australia   Mohammad Asif  20.0       6    41        6     2.05   101
# 1   Australia   Mohammad Sami  12.0       4    27        3     2.25    59
# 2   Australia        Umar Gul  10.2       0    38        1     3.67    47
# 3   Australia  Danish Kaneria   2.0       0    18        0     9.00     5
# 4    Pakistan  Doug Bollinger  21.5       5    72        4     3.29   105
#
#    fours  sixes  wides  no balls   Match Number
# 0      5      0      0         0  Test no. 1945
# 1      4      0      0         1  Test no. 1945
# 2      6      0      1         0  Test no. 1945
# 3      2      1      0         0  Test no. 1945
# 4      8      0      1         6  Test no. 1945

# %%
bowling_df = bowling_df.rename(columns={'Match Number': 'Match id'})
bowling_df['Match id'] = bowling_df['Match id'].str.replace("Test no. ","").str.strip()

# %%
bowling_df = bowling_df.drop(columns=['match_name_x','Match','match_name_y'],axis = 'columns')

# %%
bowling_df.head()
# Out:
#   teamInnings     Bowler Name  Over  Maiden  Runs  Wickets  Economy  dots  \
# 0   Australia   Mohammad Asif  20.0       6    41        6     2.05   101
# 1   Australia   Mohammad Sami  12.0       4    27        3     2.25    59
# 2   Australia        Umar Gul  10.2       0    38        1     3.67    47
# 3   Australia  Danish Kaneria   2.0       0    18        0     9.00     5
# 4    Pakistan  Doug Bollinger  21.5       5    72        4     3.29   105
#
#    fours  sixes  wides  no balls Match id
# 0      5      0      0         0     1945
# 1      4      0      0         1     1945
# 2      6      0      1         0     1945
# 3      2      1      0         0     1945
# 4      8      0      1         6     1945

# %%
match_df = test_info_df[['Match id', 'Match']]
match_df = match_df.rename(columns={'Match': 'match_name'})
bowling_df = pd.merge(bowling_df, match_df, on='Match id', how='left')

# %%
bowling_df[['team1', 'team2']] = bowling_df['match_name'].str.split(' vs ', expand=True)

# %%
bowling_df['teamInnings'] = np.where(bowling_df['teamInnings'] == bowling_df['team1'], bowling_df['team2'], bowling_df['team1'])

# %% [markdown]
# # save the edited bowling dataframe in the csv

# %%
bowling_df.to_csv("test_bowling_data.csv",index=False)

# %% [markdown]
# # Edit the test batting data

# %%
batting_df = pd.read_csv("test_batting_data.csv")
batting_df.head()
# Out:
#   teamInnings  Batting Position       Batsman Name  \
# 0   Australia                 1       Shane Watson
# 1   Australia                 2     Phillip Hughes
# 2   Australia                 3  Ricky Ponting (c)
# 3   Australia                 4     Michael Hussey
# 4   Australia                 5     Michael Clarke
#
#                          Dismissal Runs Balls   M 4s 6s Strike Rate  \
# 0  c †Kamran Akmal b Mohammad Sami    6    24  39  1  0       25.00
# 1   c Faisal Iqbal b Mohammad Sami    0    10  15  0  0        0.00
# 2       c Umar Gul b Mohammad Sami    0     1   1  0  0        0.00
# 3  c Misbah-ul-Haq b Mohammad Asif   28    52  96  4  0       53.84
# 4                  b Mohammad Asif    3    30  50  0  0       10.00
#
#     Match Number
# 0  Test no. 1945
# 1  Test no. 1945
# 2  Test no. 1945
# 3  Test no. 1945
# 4  Test no. 1945

# %%
batting_df = batting_df.rename(columns={'Match Number': 'Match id'})
batting_df['Match id'] = batting_df['Match id'].str.replace("Test no. ","").str.strip()

# %%
batting_df = pd.merge(batting_df, match_df, on='Match id', how='left')

# %%
batting_df.to_csv("test_batting_data.csv",index=False)
